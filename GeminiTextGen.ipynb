# %%
#pip install -q -U google-generativeai

# %%
import os
os.environ["GEMINI_API_KEY"]="ENTER API_KEY"

# %%
import os
import google.generativeai as genai   # ✅ correct import

# Configure with your API key
genai.configure(api_key=os.environ["GEMINI_API_KEY"])

# %%
model = genai.GenerativeModel("models/gemini-2.5-flash-preview-09-2025")

# %%
response = model.generate_content('tabular format of the answer difference between ai and ml')
print(response.text)
# Out:
# ## AI vs. ML: Key Differences
#
# | Feature | Artificial Intelligence (AI) | Machine Learning (ML) |
# | :--- | :--- | :--- |
# | **Definition** | The broad concept of creating **intelligent systems** that can simulate human thought and behavior. | A **subset of AI** that focuses on enabling systems to learn from data without being explicitly programmed. |
# | **Goal** | To create **intelligent** machines that can solve complex problems, reason, perceive, and act rationally. | To allow systems to **learn from data** and improve their performance on a specific task over time. |
# | **Scope** | **Wider** field, encompassing ML, Deep Learning, Robotics, Computer Vision, Natural Language Processing, and Expert Systems. | **Narrower** field, primarily focused on algorithms and statistical models that enable learning from data. |
# | **How it Works** | Uses various techniques (including ML) to achieve intelligent behavior, often involving symbolic reasoning and rule-based systems. | Works by feeding large amounts of data to an algorithm, allowing the algorithm to automatically discover patterns and make predictions/decisions. |
# | **Dependency** | ML is a **tool** or method used to achieve AI. Not all AI requires ML (e.g., old expert systems). | ML is **dependent** on the overarching field of AI; it is fundamentally a part of AI. |
# | **Type of System** | Aims for **general intelligence** (or strong AI, though largely theoretical) or robust, goal-oriented behavior. | Focuses on **specific tasks** (e.g., classification, regression, clustering) where the system needs to derive knowledge from data. |
# | **Analogy** | The entire **human brain** and the goal of replicating its overall intelligence. | A specific **cognitive function** of the brain, like the ability to learn from experience. |
# | **Key Output** | A system that can make human-like decisions and actions (e.g., a self-driving car managing traffic). | An accurate model or algorithm that makes predictions based on trained data (e.g., predicting stock prices). |

# %%
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import  display
from IPython.display import Markdown

def to_markdown(text):
    text = text.replace('•',' *')
    return Markdown(textwrap.indent(text,'> ',predicate=lambda _: True))

# %%
for m in genai.list_models():
    if 'generateContent' in m.supported_generation_methods:
        print(m.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-flash-lite-preview
# models/gemini-exp-1206
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/gemma-3n-e4b-it
# models/gemma-3n-e2b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image-preview
# models/gemini-2.5-flash-image
# models/gemini-2.5-flash-preview-09-2025
# models/gemini-2.5-flash-lite-preview-09-2025
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3-pro-image-preview
# models/nano-banana-pro-preview
# models/gemini-robotics-er-1.5-preview
# models/gemini-2.5-computer-use-preview-10-2025
# models/deep-research-pro-preview-12-2025
