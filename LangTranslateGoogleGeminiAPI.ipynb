# %%
#pip install -U langchain-google-genai

# %%
import getpass
import os
from langchain_google_genai import ChatGoogleGenerativeAI

if not os.environ.get("GOOGLE_API_KEY"):
    os.environ["GOOGLE_API_KEY"]="use_your_api_key"
    
from langchain.chat_models import init_chat_model

model = ChatGoogleGenerativeAI(model='gemini-2.5-flash-lite')

# %%
model.invoke("Who is the President of India")
# Out:
# AIMessage(content='The current President of India is **Droupadi Murmu**.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b1261-bbc1-77f3-9378-ed76cbceaf79-0', usage_metadata={'input_tokens': 7, 'output_tokens': 13, 'total_tokens': 20, 'input_token_details': {'cache_read': 0}})

# %%
model.invoke("Who is the President of India").content
# Out:
# 'The current President of India is **Droupadi Murmu**.'

# %%
from langchain_core.messages import HumanMessage,SystemMessage

messages=[
    SystemMessage("Translate the following from english into odia language"),
    HumanMessage("how are you team working on langchain with google gemini model?")    
]
model.invoke(messages)
# Out:
# AIMessage(content='Google Gemini-ମଡେଲ୍ ସହିତ Langchain ଟିମ୍ କିପରି କାର୍ଯ୍ୟ କରୁଛି?', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b1263-2e8a-7621-a1a8-beae9b2cd047-0', usage_metadata={'input_tokens': 23, 'output_tokens': 30, 'total_tokens': 53, 'input_token_details': {'cache_read': 0}})

# %%
from langchain_core.messages import HumanMessage,SystemMessage

messages=[
    SystemMessage("Translate the following from english into odia language"),
    HumanMessage("how are you team working on langchain with google gemini model?")    
]
model.invoke(messages).content
# Out:
# '"ଆପଣଙ୍କ ଲାଙ୍ଗ୍ଚେନ୍ (Langchain) ଟିମ୍ ଗୁଗୁଲ୍ ଜେମିନାଇ (Google Gemini) ମଡେଲ୍ ସହିତ କିପରି କାମ କରୁଛି?"\n\nଏହି ବାକ୍ୟରେ "team working on langchain with google gemini model" ଅଂଶର ଓଡ଼ିଆ ଅନୁବାଦ ହେଉଛି "ଲାଙ୍ଗ୍ଚେନ୍ ଟିମ୍ ଗୁଗୁଲ୍ ଜେମିନାଇ ମଡେଲ୍ ସହିତ କାମ କରୁଛି"।\n\n"How are you" ପାଇଁ "ଆପଣଙ୍କ" ବ୍ୟବହୃତ ହୋଇଛି, ଯାହା ଏକ ସମ୍ମାନଜନକ ପ୍ରଶ୍ନ ପଚାରିବାକୁ ବ୍ୟବହୃତ ହୁଏ।'

# %%
from langchain_core.messages import HumanMessage,SystemMessage

messages=[
    SystemMessage("Translate the following from english into Marathi language"),
    HumanMessage("how are you team working on langchain with google gemini model?")    
]
model.invoke(messages).content
# Out:
# 'मी Google Gemini मॉडेलवर काम करणाऱ्या LangChain टीमसोबत काम करत आहे.'

# %%
from langchain_core.messages import HumanMessage,SystemMessage

messages=[
    SystemMessage("Translate the following from english into Hindi language"),
    HumanMessage("Hey! How are You? ")    
]
model.invoke(messages).content
# Out:
# 'नमस्ते! आप कैसे हैं?'
