# %% [markdown]
# MULTIMODEL - (Image to Text)

# %%
import os
os.environ["GEMINI_API_KEY"]="ENTER API_KEY"

# %%
import os
import google.generativeai as genai   # ✅ correct import

# Configure with your API key
genai.configure(api_key=os.environ["GEMINI_API_KEY"])
# Out:
# C:\Users\VICTUS\AppData\Local\Temp\ipykernel_552536\3764922122.py:2: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   import google.generativeai as genai   # ✅ correct import

# %%
model = genai.GenerativeModel("models/gemini-2.5-flash-preview-09-2025")

# %%
import PIL.Image

img = PIL.Image.open(r"C:\Users\VICTUS\Desktop\g3.webp")
img
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=800x534>

# %%
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import  display
from IPython.display import Markdown

def to_markdown(text):
    text = text.replace('•',' *')
    return Markdown(textwrap.indent(text,'> ',predicate=lambda _: True))

# %%
response = model.generate_content(img)
to_markdown(response.text)
# Out:
# > This is a cheerful outdoor portrait featuring three young children standing shoulder-to-shoulder, smiling happily at the camera.
# >
# > **Subjects and Interaction:**
# > The group consists of two boys and one girl, appearing to be siblings or close friends, all likely between the ages of six and nine. The central boy, who has bright red hair, stands between the other two and has his arms draped over their shoulders, creating a warm, unified pose. All three children have wide, genuine smiles.
# >
# > **Appearance Details:**
# > *   **Left Boy:** Has light brown hair and is wearing a solid royal blue short-sleeved t-shirt with a small chest pocket. He is showing a gap where a primary tooth is missing.
# > *   **Center Boy:** Has vibrant ginger/red hair and a fair complexion. He is wearing a long-sleeved shirt that is red through the body and features contrasting blue sleeves and collar trim.
# > *   **Right Girl:** Has shoulder-length blonde hair, accented by a white cloth headband/bow. She is wearing a soft sage green or teal top with ruched detailing at the neckline and short sleeves featuring eyelet or patterned fabric.
# >
# > **Setting:**
# > The photograph was taken outdoors, likely in a park or wooded area. The background is softly blurred (shallow depth of field), focusing attention entirely on the children. Visible elements in the background include dark green foliage and the rough, textured trunk of a large tree on the right side of the frame. The lighting is soft and natural.
