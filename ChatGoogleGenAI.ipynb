# %%
# %pip install  -U langchain-google-genai
# Out:
# Requirement already satisfied: langchain-google-genai in c:\users\victus\appdata\local\programs\python\python313\lib\site-packages (3.2.0)Note: you may need to restart the kernel to use updated packages.
#
# Collecting langchain-google-genai
#   Downloading langchain_google_genai-4.0.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\victus\appdata\local\programs\python\python313\lib\site-packages (from langchain-google-genai) (1.2.0)
# Collecting google-genai<2.0.0,>=1.53.0 (from langchain-google-genai)
#   Downloading google_genai-1.54.0-py3-none-any.whl.metadata (47 kB)
# Collecting langchain-core<2.0.0,>=1.1.2 (from langchain-google-genai)
#   Downloading langchain_core-1.1.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in c:\users\victus\appdata\local\programs\python\python313\lib\site-packages (from langchain-google-genai) (2.11.7)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in c:\users\victus\appdata\local\programs\python\python313\lib\site-packages (from google-genai<2.0.0,>=1.53.0->langchain-google-genai) (4.10.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in c:\users\victus\appdata\local\programs\python\python313\lib\site-packages (from google-auth[requests]<3.0.0,>=2.14.1->google-genai<2.0.0,>=1.53.0->langchain-google-genai) (2.42.1)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in c:\users\victus\appdata\local\programs\python\python313\lib\site-packages (from google-genai<2.0.0,>=1.53.0->langchain-google-genai) (0.28.1)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in c:\users\victus\appdata\local\programs\python\python313\lib\site-packages (from google-genai<2.0.0,>=1.53.0->langchain-google-genai) (2.32.4)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in c:\users\victus\appdata\local\programs\python\python313\lib\site-packages (from google-genai<2.0.0,>=1.53.0->langchain-google-genai) (9.1.2)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in c:\users\victus\appdata\local\programs\python\python313\lib\site-packages (from google-genai<2.0.0,>=1.53.0->langchain-google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in c:\users\victus\appdata\local\programs\python\python313\lib\site-packages (from google-genai<2.0.0,>=1.53.0->langchain-google-genai) (4.14.1)
# Requirement already satisfied: idna>=2.8 in c:\users\victus\appdata\local\programs\python\python313\lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.53.0->langchain-google-genai) (3.10)
# Requirement already satisfied: sniffio>=1.1 in c:\users\victus\appdata\local\programs\python\python313\lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.53.0->langchain-google-genai) (1.3.1)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\victus\appdata\local\programs\python\python313\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-auth[requests]<3.0.0,>=2.14.1->google-genai<2.0.0,>=1.53.0->langchain-google-genai) (6.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\victus\appdata\local\programs\python\python313\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-auth[requests]<3.0.0,>=2.14.1->google-genai<2.0.0,>=1.53.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\victus\appdata\local\programs\python\python313\lib\site-packages (from google-auth<3.0.0,>=2.14.1->google-auth[requests]<3.0.0,>=2.14.1->google-genai<2.0.0,>=1.53.0->langchain-google-genai) (4.9.1)
# Requirement already satisfied: certifi in c:\users\victus\appdata\local\programs\python\python313\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.53.0->langchain-google-genai) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\victus\appdata\local\programs\python\python313\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.53.0->langchain-google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\victus\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.53.0->langchain-google-genai) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\victus\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.1.2->langchain-google-genai) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\victus\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.1.2->langchain-google-genai) (0.4.40)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\victus\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.1.2->langchain-google-genai) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\victus\appdata\local\programs\python\python313\lib\site-packages (from langchain-core<2.0.0,>=1.1.2->langchain-google-genai) (6.0.2)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core<2.0.0,>=1.1.2->langchain-google-genai)
#   Downloading uuid_utils-0.12.0-cp39-abi3-win_amd64.whl.metadata (1.1 kB)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\victus\appdata\local\programs\python\python313\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.2->langchain-google-genai) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\victus\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.2->langchain-google-genai) (3.11.3)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\victus\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.2->langchain-google-genai) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\victus\appdata\local\programs\python\python313\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.2->langchain-google-genai) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\victus\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\victus\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\victus\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\victus\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai<2.0.0,>=1.53.0->langchain-google-genai) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\victus\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai<2.0.0,>=1.53.0->langchain-google-genai) (2.5.0)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\victus\appdata\local\programs\python\python313\lib\site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.14.1->google-auth[requests]<3.0.0,>=2.14.1->google-genai<2.0.0,>=1.53.0->langchain-google-genai) (0.6.1)
# Downloading langchain_google_genai-4.0.0-py3-none-any.whl (63 kB)
# Downloading google_genai-1.54.0-py3-none-any.whl (262 kB)
# Downloading langchain_core-1.1.3-py3-none-any.whl (475 kB)
# Downloading uuid_utils-0.12.0-cp39-abi3-win_amd64.whl (183 kB)
# Installing collected packages: uuid-utils, langchain-core, google-genai, langchain-google-genai
#
#    ---------------------------------------- 0/4 [uuid-utils]
#   Attempting uninstall: langchain-core
#    ---------------------------------------- 0/4 [uuid-utils]
#     Found existing installation: langchain-core 1.1.0
#    ---------------------------------------- 0/4 [uuid-utils]
#    ---------- ----------------------------- 1/4 [langchain-core]
#     Uninstalling langchain-core-1.1.0:
#    ---------- ----------------------------- 1/4 [langchain-core]
#       Successfully uninstalled langchain-core-1.1.0
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    ---------- ----------------------------- 1/4 [langchain-core]
#    -------------------- ------------------- 2/4 [google-genai]
#    -------------------- ------------------- 2/4 [google-genai]
#    -------------------- ------------------- 2/4 [google-genai]
#    -------------------- ------------------- 2/4 [google-genai]
#    -------------------- ------------------- 2/4 [google-genai]
#    -------------------- ------------------- 2/4 [google-genai]
#    -------------------- ------------------- 2/4 [google-genai]
#    -------------------- ------------------- 2/4 [google-genai]
#    -------------------- ------------------- 2/4 [google-genai]
#    -------------------- ------------------- 2/4 [google-genai]
#    -------------------- ------------------- 2/4 [google-genai]
#    -------------------- ------------------- 2/4 [google-genai]
#    -------------------- ------------------- 2/4 [google-genai]
#    -------------------- ------------------- 2/4 [google-genai]
#   Attempting uninstall: langchain-google-genai
#    -------------------- ------------------- 2/4 [google-genai]
#     Found existing installation: langchain-google-genai 3.2.0
#    -------------------- ------------------- 2/4 [google-genai]
#    ------------------------------ --------- 3/4 [langchain-google-genai]
#     Uninstalling langchain-google-genai-3.2.0:
#    ------------------------------ --------- 3/4 [langchain-google-genai]
#       Successfully uninstalled langchain-google-genai-3.2.0
#    ------------------------------ --------- 3/4 [langchain-google-genai]
#    ------------------------------ --------- 3/4 [langchain-google-genai]
#    ------------------------------ --------- 3/4 [langchain-google-genai]
#    ---------------------------------------- 4/4 [langchain-google-genai]
#
# Successfully installed google-genai-1.54.0 langchain-core-1.1.3 langchain-google-genai-4.0.0 uuid-utils-0.12.0

# %%
import getpass
import os
from langchain_google_genai import ChatGoogleGenerativeAI

if not os.environ.get("GOOGLE_API_KEY"):
    os.environ["GOOGLE_API_KEY"]="key"
    
from langchain.chat_models import init_chat_model

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")
